# %%
import numpy as np
import pandas as pd
import plotly.express as px

import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("white")
# %matplotlib inline

# %%
cohort_stats=pd.read_pickle('cohort_stats.pkl')

# %%
cohort_stats
# Out:
#    year  no_cohort_donors_y1  no_donations_y1  amt_donated_y1  \
# 0  2013               320102           573983     30428184.74
# 1  2014               320675           461349     26174346.80
# 2  2015               355141           468186     30147004.32
# 3  2016               445598           602717     36530214.52
# 4  2017               434994           668561     37973855.48
#
#    no_cohort_donors_y2  no_donations_y2  amt_donated_y2  no_cohort_donors_y3  \
# 0              62142.0         285259.0     15286871.11              42240.0
# 1              48667.0         131028.0      7745897.26              31525.0
# 2              46078.0         112446.0      8280549.87              31844.0
# 3              56538.0         177433.0     10475760.27                  NaN
# 4                  NaN              NaN             NaN                  NaN
#
#    no_donations_y3  amt_donated_y3  no_cohort_donors_y4  no_donations_yr4  \
# ...

# %%
cohort_stats['donor_retention_rate_yr2']=cohort_stats.no_cohort_donors_y2/cohort_stats.no_cohort_donors_y1*100
cohort_stats['donor_retention_rate_yr3']=cohort_stats.no_cohort_donors_y3/cohort_stats.no_cohort_donors_y2*100
cohort_stats['donor_retention_rate_yr4']=cohort_stats.no_cohort_donors_y4/cohort_stats.no_cohort_donors_y3*100
cohort_stats['donor_retention_rate_yr5']=cohort_stats.no_cohort_donors_y5/cohort_stats.no_cohort_donors_y4*100

# %%
cohort_stats.head()
# Out:
#    year  no_cohort_donors_y1  no_donations_y1  amt_donated_y1  \
# 0  2013               320102           573983     30428184.74
# 1  2014               320675           461349     26174346.80
# 2  2015               355141           468186     30147004.32
# 3  2016               445598           602717     36530214.52
# 4  2017               434994           668561     37973855.48
#
#    no_cohort_donors_y2  no_donations_y2  amt_donated_y2  no_cohort_donors_y3  \
# 0              62142.0         285259.0     15286871.11              42240.0
# 1              48667.0         131028.0      7745897.26              31525.0
# 2              46078.0         112446.0      8280549.87              31844.0
# 3              56538.0         177433.0     10475760.27                  NaN
# 4                  NaN              NaN             NaN                  NaN
#
#    no_donations_y3  amt_donated_y3  no_cohort_donors_y4  no_donations_yr4  \
# ...

# %%
cohort_stats.to_csv('cohort_stat.csv')
