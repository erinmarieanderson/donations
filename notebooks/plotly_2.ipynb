# %%
import datetime
import numpy as np
import pandas as pd

import plotly.graph_objects as go
from ipywidgets import widgets

# %%
df = pd.read_csv(
    'https://raw.githubusercontent.com/yankev/testing/master/datasets/nycflights.csv')
df = df.drop(df.columns[[0]], axis=1)

# %%
df['carrier'].unique()
# Out:
# array(['UA', 'AA', 'B6', 'DL', 'EV', 'MQ', 'US', 'WN', 'VX', 'FL', 'AS',
#        '9E', 'F9', 'HA', 'YV', 'OO'], dtype=object)

# %%
month = widgets.IntSlider(
    value=1.0,
    min=1.0,
    max=12.0,
    step=1.0,
    description='Month:',
    continuous_update=False
)

use_date = widgets.Checkbox(
    description='Date: ',
    value=True,
)

container = widgets.HBox(children=[use_date, month])

textbox = widgets.Dropdown(
    description='Airline:   ',
    value='DL',
    options=df['carrier'].unique().tolist()
)

origin = widgets.Dropdown(
    options=list(df['origin'].unique()),
    value='LGA',
    description='Origin Airport:',
)


# Assign an empty figure widget with two traces
trace1 = go.Histogram(x=df['arr_delay'], opacity=0.75, name='Arrival Delays')
trace2 = go.Histogram(x=df['dep_delay'], opacity=0.75, name='Departure Delays')
g = go.FigureWidget(data=[trace1, trace2],
                    layout=go.Layout(
                        title=dict(
                            text='NYC FlightDatabase'
                        ),
                        barmode='overlay'
                    ))

# %%
def validate():
    if origin.value in df['origin'].unique() and textbox.value in df['carrier'].unique():
        return True
    else:
        return False


def response(change):
    if validate():
        if use_date.value:
            filter_list = [i and j and k for i, j, k in
                           zip(df['month'] == month.value, df['carrier'] == textbox.value,
                               df['origin'] == origin.value)]
            temp_df = df[filter_list]

        else:
            filter_list = [i and j for i, j in
                           zip(df['carrier'] == 'DL', df['origin'] == origin.value)]
            temp_df = df[filter_list]
        x1 = temp_df['arr_delay']
        x2 = temp_df['dep_delay']
        with g.batch_update():
            g.data[0].x = x1
            g.data[1].x = x2
            g.layout.barmode = 'overlay'
            g.layout.xaxis.title = 'Delay in Minutes'
            g.layout.yaxis.title = 'Number of Delays'


origin.observe(response, names="value")
textbox.observe(response, names="value")
month.observe(response, names="value")
use_date.observe(response, names="value")

# %%
container2 = widgets.HBox([origin, textbox])
widgets.VBox([container,
              container2,
              g])
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'origin'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\ipywidgets\widgets\widget.py in _handle_msg(self, msg)
# ...

# %%
#df = pd.read_pickle('donations_13to17.pkl')
df1 = pd.read_csv('yr_sample.csv')
df1
#df = df.drop(df.columns[[0]], axis=1)
# Out:
#        Unnamed: 0                                id first_year_gift  \
# 0               6  5ed977146450419ce58267c24b8b1d45      2013-01-01
# 1              38  7935c496fa642a80aeb5a33f11fc1520      2013-01-01
# 2             220  c1f9f36453d96bb9a9ba50cc32bd3c0c      2013-01-01
# 3             408  2bf0e8d016eaee8ecdd0ccc6d827285f      2013-01-01
# 4             609  963be1b11760744f55616537923d4785      2013-01-01
# ...           ...                               ...             ...
# 45168     1799837  6812dd98e74cf65c4089c82d61a4036c      2013-01-01
# 45169     1799872  18269fe4efb18654dc5a8187d373be2f      2014-01-01
# 45170     1799913  20a70478927067768e69f44af0b4a5d0      2017-01-01
# 45171     1799915  9899fb6e3187019f7fb3bb06cc5e440b      2017-01-01
# 45172     1799999  e4454046671c5f24f536a0ad8dd1aff7      2015-01-01
#
#        years_donated  perc_years_donated donor_profile behavior_2013  \
# 0                1.0                 0.2      one_time           new
# ...

# %%
df1['year'] = pd.DatetimeIndex(df1['date']).year
df1
# Out:
#        Unnamed: 0                                id first_year_gift  \
# 0               6  5ed977146450419ce58267c24b8b1d45      2013-01-01
# 1              38  7935c496fa642a80aeb5a33f11fc1520      2013-01-01
# 2             220  c1f9f36453d96bb9a9ba50cc32bd3c0c      2013-01-01
# 3             408  2bf0e8d016eaee8ecdd0ccc6d827285f      2013-01-01
# 4             609  963be1b11760744f55616537923d4785      2013-01-01
# ...           ...                               ...             ...
# 45168     1799837  6812dd98e74cf65c4089c82d61a4036c      2013-01-01
# 45169     1799872  18269fe4efb18654dc5a8187d373be2f      2014-01-01
# 45170     1799913  20a70478927067768e69f44af0b4a5d0      2017-01-01
# 45171     1799915  9899fb6e3187019f7fb3bb06cc5e440b      2017-01-01
# 45172     1799999  e4454046671c5f24f536a0ad8dd1aff7      2015-01-01
#
#        years_donated  perc_years_donated donor_profile behavior_2013  \
# 0                1.0                 0.2      one_time           new
# ...

# %%
df=df1.groupby(['year', 'donor_profile', 'years_donated', 'first_year_gift'], as_index=False).sum()

# %%
df.head()
# Out:
#    year donor_profile  years_donated first_year_gift  Unnamed: 0  \
# 0  2013      one_time            1.0      2013-01-01   843660269
# 1  2013        repeat            2.0      2013-01-01   230903687
# 2  2013        repeat            3.0      2013-01-01   117498849
# 3  2013        repeat            4.0      2013-01-01    60463344
# 4  2013        repeat            5.0      2013-01-01    92551835
#
#    perc_years_donated  gainloss_2017_amt     amount
# 0               803.8               0.00  246089.69
# 1               408.4           -1053.08  113537.07
# 2               301.2           -8733.39   50268.29
# 3               216.8          -62154.44   21179.43
# 4               433.0           24031.56   53413.24

# %%
month = widgets.IntSlider(
    value=2013,
    min=2013,
    max=2017,
    step=1.0,
    description='Year:',
    continuous_update=False
)

#use_date = widgets.Checkbox(
#    description='Date: ',
#    value=True,
#)

container = widgets.HBox(children=[month])

# donor_profile
textbox = widgets.Dropdown(
    description='Years Donated:   ',
    value=1.0,
    options=df['years_donated'].unique().tolist()
)

#first_yr_gift
origin = widgets.Dropdown(
    options=list(df['first_year_gift'].unique()),
    value='2013-01-01',
    description='First Year Gift:',
)


# Assign an empty figure widget with two traces
trace1 = go.Bar(x=df['donor_profile'], y=df['amount'], opacity=0.75, name='Amount')
trace2 = go.Bar(x=df['donor_profile'], y=df['gainloss_2017_amt'], opacity=0.75, name='Gainloss_2017_amt')
g = go.FigureWidget(data=[trace1, trace2],
                    layout=go.Layout(
                        title=dict(
                            text='NYC FlightDatabase'
                        ),
                        barmode='overlay'
                    ))

# %%
def validate():
    if origin.value in df['first_year_gift'].unique() and textbox.value in df['years_donated'].unique():
        return True
    else:
        return False


def response(change):
    if validate():
        if use_date.value:
            filter_list = [i and j and k for i, j, k in
                           zip(df['year'] == month.value, df['donor_profile'] == textbox.value,
                               df['first_gift_year'] == origin.value)]
            temp_df = df[filter_list]

        else:
            filter_list = [i and j for i, j in
                           zip(df['donor_profile'] == 'DL', df['first_gift_year'] == origin.value)]
            temp_df = df[filter_list]
        x1 = temp_df['amount']
        x2 = temp_df['gainloss_2017_amt']
        with g.batch_update():
            g.data[0].x = x1
            g.data[1].x = x2
            g.layout.barmode = 'overlay'
            g.layout.xaxis.title = 'Delay in Minutes'
            g.layout.yaxis.title = 'Number of Delays'


origin.observe(response, names="value")
textbox.observe(response, names="value")
month.observe(response, names="value")
use_date.observe(response, names="value")

# %%
container2 = widgets.HBox([origin, textbox])
widgets.VBox([container,
              container2,
              g])
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'first_gift_year'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\ipywidgets\widgets\widget.py in _handle_msg(self, msg)
# ...
